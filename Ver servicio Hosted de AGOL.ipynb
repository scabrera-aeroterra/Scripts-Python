# %%
from arcgis.gis import *
from IPython.display import display
from getpass import getpass

# %%
user=input("Ingrese usuario:")
portalpassword = getpass()
gis = GIS("https://www.arcgis.com", user, portalpassword)
# Out:
# Ingrese usuario:Gerenteoperativo
# ········
# Unable to generate token.
# Invalid username or password.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-8030fe2bce74> in <module>
#       1 user=input("Ingrese usuario:")
#       2 portalpassword = getpass()
# ----> 3 gis = GIS("https://www.arcgis.com", user, portalpassword)
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in __init__(self, url, username, password, key_file, cert_file, verify_cert, set_active, client_id, profile, **kwargs)
#     332                                    "argument when connecting to the GIS.")
#     333             else:
# --> 334                 raise e
#     335         try:
#     336             if url.lower().find("arcgis.com") > -1 and \
#
# ...

# %%
user=gis.users.me
user

# %%
url="https://services8.arcgis.com/UHGplRUHBUpsAc2S/arcgis/rest/services/Ultima_Milla_BD_V2_1/FeatureServer"

# %%
feature=arcgis.features.layer.FeatureLayerCollection(url,gis)

# %%
type (feature)
# Out:
# arcgis.features.layer.FeatureLayerCollection

# %%
feature.layers
# Out:
# []

# %%
feature.tables
# Out:
# [<Table url:"https://services8.arcgis.com/UHGplRUHBUpsAc2S/arcgis/rest/services/Ultima_Milla_BD_V2_1/FeatureServer/1">]

# %%
feature.replicas

# %%
feature.properties
# Out:
# {
#   "currentVersion": 10.61,
#   "serviceItemId": "0f1c04be0ae74402bb1bc2761c27ce31",
#   "serviceDescription": "Base de datos \u00faltima milla - Restore 201218 - V1",
#   "hasVersionedData": false,
#   "supportsDisconnectedEditing": false,
#   "hasStaticData": false,
#   "maxRecordCount": 2000,
#   "supportedQueryFormats": "JSON",
#   "supportsVCSProjection": false,
#   "capabilities": "Create,Delete,Query,Update,Editing,Sync",
#   "description": "",
#   "copyrightText": "",
#   "spatialReference": {
#     "wkid": 4326,
#     "latestWkid": 4326
#   },
#   "initialExtent": {
#     "xmin": -58.394861288811114,
#     "ymin": -34.63555633948367,
#     "xmax": -58.37182499252464,
#     "ymax": -34.61752839020204,
#     "spatialReference": {
#       "wkid": 4326,
#       "latestWkid": 4326
#     }
#   },
#   "fullExtent": {
#     "xmin": -58.52962638855868,
#     "ymin": -34.69504766666668,
#     "xmax": -37.170787641763326,
#     "ymax": -18.215978077130668,
# ...

# %%
feature.manager.refresh()
# Out:
# {'success': True}

# %%
feature.layers
# Out:
# []

# %%
feature.manager.properties
# Out:
# {
#   "adminServiceInfo": {
#     "name": "Ultima_Milla_BD_V2_1",
#     "type": "FeatureServer",
#     "cacheMaxAge": 0,
#     "status": "Started",
#     "database": {
#       "datasource": {
#         "name": "db"
#       }
#     }
#   },
#   "preserveLayerIds": true,
#   "currentVersion": 10.61,
#   "serviceItemId": "0f1c04be0ae74402bb1bc2761c27ce31",
#   "serviceDescription": "Base de datos \u00faltima milla - Restore 201218 - V1",
#   "hasVersionedData": false,
#   "supportsDisconnectedEditing": false,
#   "hasStaticData": false,
#   "maxRecordCount": 2000,
#   "supportedQueryFormats": "JSON",
#   "supportsVCSProjection": false,
#   "capabilities": "Create,Delete,Query,Update,Editing,Sync",
#   "description": "",
#   "copyrightText": "",
#   "spatialReference": {
#     "wkid": 4326,
#     "latestWkid": 4326
#   },
#   "initialExtent": {
#     "xmin": -58.394861288811114,
#     "ymin": -34.63555633948367,
#     "xmax": -58.37182499252464,
#     "ymax": -34.61752839020204,
# ...
